# %% [markdown]
# # Xor with Pytorch

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# Imports
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from pathlib import Path

# %% [markdown]
# Create dataset

# %%
def xor_data_norm(num):
    """ Crete dataset """
    x1 = np.random.randn(num)
    x2 = np.random.randn(num)
    x = np.stack([x1, x2], axis=1).astype('float32')
    y = 2.0 * np.logical_xor(x1 >= 0, x2 >= 0).astype('float32') - 1.0
    return torch.Tensor(x), torch.Tensor(y)

# %% [markdown]
# Create model

# %%
# Trivial xor example
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layer_1 = nn.Linear(2,3)
        self.layer_2 = nn.Linear(3,1)

    def forward(self, x):
        x = self.layer_1(x)
        x = torch.tanh(x)
        x = self.layer_2(x)
        out = torch.tanh(x)
        return out

# %% [markdown]
# Train model

# %%
def train(model, x_train, y_train, epochs, lr, momentum):
    device = torch.device("cpu")
    model.train()
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=momentum)
    for n_epoch in range(epochs):
        optimizer.zero_grad()
        output = model(x_train)
        loss = F.mse_loss(output.squeeze(), y_train)
        loss.backward()
        optimizer.step()
        if n_epoch % 50 == 0:
            print(f"Train Epoch: {n_epoch} / {epochs}\tLoss: {loss.item():.6f}")

# %%
x_train, y_train = xor_data_norm(200)
model = Net()
train(model, x_train, y_train, epochs=1000, lr=0.1, momentum=0.8)
# Out:
# Train Epoch: 0 / 1000	Loss: 1.319354
# Train Epoch: 50 / 1000	Loss: 0.555735
# Train Epoch: 100 / 1000	Loss: 0.331417
# Train Epoch: 150 / 1000	Loss: 0.300821
# Train Epoch: 200 / 1000	Loss: 0.286723
# Train Epoch: 250 / 1000	Loss: 0.273188
# Train Epoch: 300 / 1000	Loss: 0.261288
# Train Epoch: 350 / 1000	Loss: 0.251910
# Train Epoch: 400 / 1000	Loss: 0.244288
# Train Epoch: 450 / 1000	Loss: 0.237911
# Train Epoch: 500 / 1000	Loss: 0.232459
# Train Epoch: 550 / 1000	Loss: 0.227714
# Train Epoch: 600 / 1000	Loss: 0.223526
# Train Epoch: 650 / 1000	Loss: 0.219781
# Train Epoch: 700 / 1000	Loss: 0.216396
# Train Epoch: 750 / 1000	Loss: 0.213305
# Train Epoch: 800 / 1000	Loss: 0.210458
# Train Epoch: 850 / 1000	Loss: 0.207818
# Train Epoch: 900 / 1000	Loss: 0.205354
# Train Epoch: 950 / 1000	Loss: 0.203044

# %%
yhat = model(x_train)
for i in range(len(yhat)):
    print(f"{y_train[i]}\t{yhat[i]}\t{x_train[i]}")
# Out:
# -1.0	tensor([-0.9998], grad_fn=<SelectBackward>)	tensor([-0.7255, -1.1244])
# 1.0	tensor([0.8243], grad_fn=<SelectBackward>)	tensor([-1.4754,  0.3054])
# 1.0	tensor([0.9379], grad_fn=<SelectBackward>)	tensor([-0.7424,  1.4179])
# 1.0	tensor([0.9420], grad_fn=<SelectBackward>)	tensor([-1.1608,  0.7481])
# 1.0	tensor([0.8939], grad_fn=<SelectBackward>)	tensor([-0.3379,  0.7636])
# -1.0	tensor([0.2243], grad_fn=<SelectBackward>)	tensor([0.2254, 0.3043])
# -1.0	tensor([-0.9941], grad_fn=<SelectBackward>)	tensor([-0.8516, -1.5214])
# 1.0	tensor([0.9997], grad_fn=<SelectBackward>)	tensor([ 0.0846, -1.2480])
# -1.0	tensor([-0.8849], grad_fn=<SelectBackward>)	tensor([0.5239, 0.3885])
# 1.0	tensor([0.8671], grad_fn=<SelectBackward>)	tensor([-0.2447,  0.6292])
# 1.0	tensor([0.7243], grad_fn=<SelectBackward>)	tensor([ 0.4038, -0.1537])
# 1.0	tensor([0.8933], grad_fn=<SelectBackward>)	tensor([-0.4299,  0.4050])
# 1.0	tensor([0.9999], grad_fn=<SelectBackward>)	tensor([ 3.2612, -0.8684])
# 1.0	tensor([0.8726], grad_fn=<SelectBackward>)	tensor([ 0.8856, -0.0561])
# 1.0	tensor([0.9999], grad_fn=<SelectBackward>)	tensor([ 0.7641, -0.7427])
# 1.0	tensor([-0.0235], grad_fn=<SelectBackward>)	tensor([-0.0448,  2.1245])
# 1.0	tensor([0.7506], grad_fn=<SelectBackward>)	tensor([-0.7380,  0.1190])
# 1.0	tensor([0.7151], grad_fn=<SelectBackward>)	tensor([-0.0534,  0.1278])
# 1.0	tensor([0.7023], grad_fn=<SelectBackward>)	tensor([-0.4430,  0.0515])
# 1.0	tensor([0.9997], grad_fn=<SelectBackward>)	tensor([ 3.0346, -0.8866])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-0.9866, -0.8342])
# 1.0	tensor([0.5914], grad_fn=<SelectBackward>)	tensor([ 1.3939, -1.4550])
# 1.0	tensor([0.9547], grad_fn=<SelectBackward>)	tensor([ 3.1925, -1.2170])
# 1.0	tensor([0.9296], grad_fn=<SelectBackward>)	tensor([-0.5871,  0.8743])
# -1.0	tensor([-0.9999], grad_fn=<SelectBackward>)	tensor([-0.9653, -0.6915])
# 1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([ 1.9257, -0.4586])
# 1.0	tensor([0.9998], grad_fn=<SelectBackward>)	tensor([ 0.2928, -1.0761])
# 1.0	tensor([0.9999], grad_fn=<SelectBackward>)	tensor([ 1.3094, -0.5813])
# 1.0	tensor([0.3533], grad_fn=<SelectBackward>)	tensor([-1.4411,  0.0907])
# -1.0	tensor([-0.9997], grad_fn=<SelectBackward>)	tensor([-0.6831, -0.7145])
# -1.0	tensor([-0.9989], grad_fn=<SelectBackward>)	tensor([0.8784, 0.5339])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-1.7996, -1.0915])
# 1.0	tensor([0.9392], grad_fn=<SelectBackward>)	tensor([-0.8160,  0.7847])
# -1.0	tensor([-0.9997], grad_fn=<SelectBackward>)	tensor([-0.6001, -0.7758])
# 1.0	tensor([0.9991], grad_fn=<SelectBackward>)	tensor([ 1.4971, -0.7723])
# 1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([ 1.0724, -0.5176])
# -1.0	tensor([-0.8698], grad_fn=<SelectBackward>)	tensor([0.6542, 0.2229])
# -1.0	tensor([-0.9999], grad_fn=<SelectBackward>)	tensor([0.5625, 2.6540])
# -1.0	tensor([-0.6783], grad_fn=<SelectBackward>)	tensor([-0.4004, -1.2616])
# -1.0	tensor([-0.9731], grad_fn=<SelectBackward>)	tensor([-0.6343, -0.4114])
# 1.0	tensor([0.9298], grad_fn=<SelectBackward>)	tensor([-0.9466,  0.5587])
# 1.0	tensor([0.8047], grad_fn=<SelectBackward>)	tensor([-0.2582,  0.1745])
# -1.0	tensor([-0.9892], grad_fn=<SelectBackward>)	tensor([0.6325, 0.5713])
# 1.0	tensor([0.5928], grad_fn=<SelectBackward>)	tensor([ 0.2255, -0.1441])
# -1.0	tensor([-0.9999], grad_fn=<SelectBackward>)	tensor([-0.8432, -1.1151])
# 1.0	tensor([0.4945], grad_fn=<SelectBackward>)	tensor([ 0.0042, -0.1199])
# 1.0	tensor([0.2084], grad_fn=<SelectBackward>)	tensor([ 0.0778, -0.3580])
# 1.0	tensor([0.7373], grad_fn=<SelectBackward>)	tensor([-1.9446,  0.3156])
# 1.0	tensor([0.5520], grad_fn=<SelectBackward>)	tensor([-0.1461,  1.8507])
# 1.0	tensor([0.4791], grad_fn=<SelectBackward>)	tensor([ 0.0871, -0.1793])
# -1.0	tensor([-0.8710], grad_fn=<SelectBackward>)	tensor([-0.5955, -0.3211])
# -1.0	tensor([-0.0669], grad_fn=<SelectBackward>)	tensor([-0.1412, -0.2553])
# -1.0	tensor([-0.9979], grad_fn=<SelectBackward>)	tensor([0.5710, 1.2515])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([1.8354, 1.2748])
# 1.0	tensor([0.4383], grad_fn=<SelectBackward>)	tensor([-0.0151,  1.2858])
# -1.0	tensor([-0.6700], grad_fn=<SelectBackward>)	tensor([-0.5276, -0.2670])
# 1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([ 0.0167, -1.5765])
# 1.0	tensor([0.9616], grad_fn=<SelectBackward>)	tensor([ 0.8098, -0.1413])
# -1.0	tensor([-0.4409], grad_fn=<SelectBackward>)	tensor([-1.5036, -0.0347])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([1.3716, 0.9940])
# 1.0	tensor([0.4399], grad_fn=<SelectBackward>)	tensor([-0.0719,  1.6309])
# 1.0	tensor([0.9633], grad_fn=<SelectBackward>)	tensor([ 0.4453, -0.3439])
# 1.0	tensor([0.9336], grad_fn=<SelectBackward>)	tensor([-0.6529,  0.8328])
# 1.0	tensor([0.9440], grad_fn=<SelectBackward>)	tensor([-0.9262,  0.9160])
# 1.0	tensor([0.9999], grad_fn=<SelectBackward>)	tensor([ 1.0021, -0.6833])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-1.0235, -1.1611])
# -1.0	tensor([-0.9074], grad_fn=<SelectBackward>)	tensor([0.8500, 0.2044])
# 1.0	tensor([0.9957], grad_fn=<SelectBackward>)	tensor([ 0.3454, -0.7323])
# -1.0	tensor([-0.3559], grad_fn=<SelectBackward>)	tensor([1.8250, 0.7503])
# -1.0	tensor([-0.9996], grad_fn=<SelectBackward>)	tensor([-0.9854, -0.5867])
# 1.0	tensor([0.9998], grad_fn=<SelectBackward>)	tensor([ 0.0859, -1.2673])
# -1.0	tensor([-0.9699], grad_fn=<SelectBackward>)	tensor([-0.7732, -1.5249])
# 1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([ 0.1493, -1.8622])
# -1.0	tensor([-0.9921], grad_fn=<SelectBackward>)	tensor([0.5631, 0.8768])
# 1.0	tensor([0.9466], grad_fn=<SelectBackward>)	tensor([ 0.3633, -0.4098])
# 1.0	tensor([0.5578], grad_fn=<SelectBackward>)	tensor([ 0.1350, -0.0650])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-1.3997, -0.9040])
# -1.0	tensor([-0.8491], grad_fn=<SelectBackward>)	tensor([-0.0960, -0.5765])
# 1.0	tensor([0.6090], grad_fn=<SelectBackward>)	tensor([ 0.2060, -0.2254])
# 1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([ 1.8639, -0.0572])
# -1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([-0.3012, -1.7847])
# -1.0	tensor([-0.2653], grad_fn=<SelectBackward>)	tensor([0.3235, 0.3670])
# 1.0	tensor([0.6050], grad_fn=<SelectBackward>)	tensor([ 0.2416, -0.1477])
# 1.0	tensor([0.9928], grad_fn=<SelectBackward>)	tensor([ 0.7734, -0.2374])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-1.4512, -1.2073])
# -1.0	tensor([-0.9998], grad_fn=<SelectBackward>)	tensor([0.9493, 0.6620])
# -1.0	tensor([-0.9991], grad_fn=<SelectBackward>)	tensor([0.7656, 0.7034])
# 1.0	tensor([0.9501], grad_fn=<SelectBackward>)	tensor([-1.1834,  1.3685])
# -1.0	tensor([-0.9993], grad_fn=<SelectBackward>)	tensor([-1.4720, -1.9994])
# 1.0	tensor([0.7168], grad_fn=<SelectBackward>)	tensor([ 1.4392, -2.4943])
# 1.0	tensor([0.9067], grad_fn=<SelectBackward>)	tensor([-0.4402,  1.2002])
# -1.0	tensor([-0.9997], grad_fn=<SelectBackward>)	tensor([-0.5786, -0.8400])
# -1.0	tensor([-0.9949], grad_fn=<SelectBackward>)	tensor([0.7507, 0.4770])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-1.8556, -0.5920])
# -1.0	tensor([-0.9831], grad_fn=<SelectBackward>)	tensor([0.3122, 2.0408])
# 1.0	tensor([0.6476], grad_fn=<SelectBackward>)	tensor([-0.0543,  1.0187])
# 1.0	tensor([0.9981], grad_fn=<SelectBackward>)	tensor([ 0.8691, -0.2569])
# 1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([ 0.4896, -2.3240])
# -1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([4.6010, 0.2000])
# 1.0	tensor([0.8545], grad_fn=<SelectBackward>)	tensor([-0.3246,  0.2784])
# -1.0	tensor([-0.9976], grad_fn=<SelectBackward>)	tensor([-0.6746, -0.5536])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-2.7363, -1.1959])
# 1.0	tensor([0.9411], grad_fn=<SelectBackward>)	tensor([-1.2962,  0.7318])
# 1.0	tensor([0.9528], grad_fn=<SelectBackward>)	tensor([-1.6838,  1.6311])
# 1.0	tensor([0.9993], grad_fn=<SelectBackward>)	tensor([ 0.9678, -0.2613])
# -1.0	tensor([-0.9998], grad_fn=<SelectBackward>)	tensor([-2.2720, -0.3778])
# 1.0	tensor([0.8115], grad_fn=<SelectBackward>)	tensor([-0.2489,  1.4226])
# 1.0	tensor([0.9508], grad_fn=<SelectBackward>)	tensor([-1.2840,  1.3191])
# 1.0	tensor([0.9952], grad_fn=<SelectBackward>)	tensor([ 1.1165, -1.0680])
# 1.0	tensor([0.8857], grad_fn=<SelectBackward>)	tensor([-0.6789,  0.3099])
# 1.0	tensor([0.9135], grad_fn=<SelectBackward>)	tensor([ 1.4446, -1.1067])
# 1.0	tensor([0.9924], grad_fn=<SelectBackward>)	tensor([ 0.0911, -1.0606])
# 1.0	tensor([0.9971], grad_fn=<SelectBackward>)	tensor([ 1.2603, -0.9059])
# 1.0	tensor([0.6990], grad_fn=<SelectBackward>)	tensor([-0.9600,  0.1202])
# 1.0	tensor([0.9486], grad_fn=<SelectBackward>)	tensor([ 1.6566, -1.0179])
# 1.0	tensor([0.8230], grad_fn=<SelectBackward>)	tensor([-0.1885,  0.2870])
# -1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([2.2511, 0.0727])
# -1.0	tensor([-0.3216], grad_fn=<SelectBackward>)	tensor([-0.0923, -0.3428])
# 1.0	tensor([0.8746], grad_fn=<SelectBackward>)	tensor([ 0.4111, -0.2491])
# 1.0	tensor([0.8746], grad_fn=<SelectBackward>)	tensor([ 1.3218, -1.2660])
# 1.0	tensor([0.9463], grad_fn=<SelectBackward>)	tensor([-1.8452,  0.9247])
# 1.0	tensor([0.9468], grad_fn=<SelectBackward>)	tensor([-1.2533,  0.8992])
# 1.0	tensor([0.4373], grad_fn=<SelectBackward>)	tensor([ 0.7779, -0.0127])
# 1.0	tensor([0.9959], grad_fn=<SelectBackward>)	tensor([ 0.4619, -0.5264])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([1.3228, 1.6974])
# -1.0	tensor([-0.5156], grad_fn=<SelectBackward>)	tensor([-0.8129, -0.1748])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([1.1399, 0.8745])
# -1.0	tensor([-0.4698], grad_fn=<SelectBackward>)	tensor([-1.3160, -0.0738])
# 1.0	tensor([0.9483], grad_fn=<SelectBackward>)	tensor([-1.0795,  1.1357])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-1.6334, -1.3148])
# -1.0	tensor([-0.5918], grad_fn=<SelectBackward>)	tensor([0.3692, 0.4686])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([1.4874, 1.0412])
# 1.0	tensor([0.7901], grad_fn=<SelectBackward>)	tensor([-0.4908,  0.1299])
# 1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([ 1.4963, -0.4691])
# 1.0	tensor([0.9999], grad_fn=<SelectBackward>)	tensor([ 0.3217, -1.1535])
# -1.0	tensor([-0.9881], grad_fn=<SelectBackward>)	tensor([-0.4158, -0.5420])
# -1.0	tensor([-0.5430], grad_fn=<SelectBackward>)	tensor([0.1929, 1.2965])
# -1.0	tensor([-0.4860], grad_fn=<SelectBackward>)	tensor([-0.3416, -0.2730])
# 1.0	tensor([0.9999], grad_fn=<SelectBackward>)	tensor([ 0.2992, -1.0962])
# -1.0	tensor([-0.2277], grad_fn=<SelectBackward>)	tensor([-0.4363, -0.1997])
# -1.0	tensor([-0.0170], grad_fn=<SelectBackward>)	tensor([0.3105, 0.2466])
# -1.0	tensor([-0.3488], grad_fn=<SelectBackward>)	tensor([-0.8021, -0.1472])
# 1.0	tensor([0.8903], grad_fn=<SelectBackward>)	tensor([-0.3274,  0.8226])
# 1.0	tensor([0.9996], grad_fn=<SelectBackward>)	tensor([ 1.1306, -0.2040])
# 1.0	tensor([0.8011], grad_fn=<SelectBackward>)	tensor([-0.6958,  0.1587])
# -1.0	tensor([-0.2338], grad_fn=<SelectBackward>)	tensor([-0.5918, -1.5046])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-1.8386, -1.3334])
# -1.0	tensor([-0.4093], grad_fn=<SelectBackward>)	tensor([0.6589, 0.0802])
# 1.0	tensor([0.1613], grad_fn=<SelectBackward>)	tensor([-1.4886,  0.0614])
# -1.0	tensor([-0.9996], grad_fn=<SelectBackward>)	tensor([0.5772, 1.8266])
# 1.0	tensor([0.8642], grad_fn=<SelectBackward>)	tensor([-0.3305,  1.3839])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([1.1848, 1.1995])
# 1.0	tensor([0.2041], grad_fn=<SelectBackward>)	tensor([ 0.0303, -0.8218])
# -1.0	tensor([-0.9999], grad_fn=<SelectBackward>)	tensor([0.7441, 1.6936])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([1.3022, 1.0233])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-1.5074, -1.2776])
# 1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([ 0.2226, -1.3202])
# 1.0	tensor([0.8148], grad_fn=<SelectBackward>)	tensor([-1.7776,  0.3485])
# 1.0	tensor([0.6127], grad_fn=<SelectBackward>)	tensor([-0.5121,  0.0112])
# 1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([ 1.8961, -0.3966])
# -1.0	tensor([-0.6638], grad_fn=<SelectBackward>)	tensor([0.3459, 0.6334])
# 1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([ 0.5698, -1.5402])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-2.0847, -0.9469])
# -1.0	tensor([-0.9610], grad_fn=<SelectBackward>)	tensor([-0.3717, -0.4733])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-1.1908, -0.9317])
# -1.0	tensor([-0.3483], grad_fn=<SelectBackward>)	tensor([0.1843, 1.1061])
# 1.0	tensor([0.9978], grad_fn=<SelectBackward>)	tensor([ 1.3078, -0.8686])
# -1.0	tensor([-0.9975], grad_fn=<SelectBackward>)	tensor([-0.3736, -0.7884])
# 1.0	tensor([0.9446], grad_fn=<SelectBackward>)	tensor([-1.1431,  0.8283])
# 1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([ 0.2432, -1.3837])
# 1.0	tensor([0.8884], grad_fn=<SelectBackward>)	tensor([-0.6382,  0.3200])
# -1.0	tensor([-0.9651], grad_fn=<SelectBackward>)	tensor([0.3204, 1.7132])
# 1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([ 1.8022, -0.4519])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-1.9020, -0.6347])
# 1.0	tensor([0.7461], grad_fn=<SelectBackward>)	tensor([-2.1803,  0.3641])
# -1.0	tensor([-0.9999], grad_fn=<SelectBackward>)	tensor([-0.8605, -0.7417])
# 1.0	tensor([0.9522], grad_fn=<SelectBackward>)	tensor([-1.7857,  1.3438])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([1.3677, 0.9114])
# 1.0	tensor([0.9999], grad_fn=<SelectBackward>)	tensor([ 1.0474, -0.7563])
# 1.0	tensor([0.9332], grad_fn=<SelectBackward>)	tensor([-1.3830,  0.6276])
# -1.0	tensor([-0.9998], grad_fn=<SelectBackward>)	tensor([-0.6412, -0.8122])
# 1.0	tensor([0.8846], grad_fn=<SelectBackward>)	tensor([-1.4440,  0.4009])
# 1.0	tensor([0.9999], grad_fn=<SelectBackward>)	tensor([ 0.9261, -0.5131])
# -1.0	tensor([0.2220], grad_fn=<SelectBackward>)	tensor([-0.6400, -0.0785])
# 1.0	tensor([0.7470], grad_fn=<SelectBackward>)	tensor([-0.1538,  1.2360])
# 1.0	tensor([0.3884], grad_fn=<SelectBackward>)	tensor([ 0.0554, -0.2197])
# 1.0	tensor([0.9496], grad_fn=<SelectBackward>)	tensor([-1.1572,  1.6638])
# -1.0	tensor([1.0000], grad_fn=<SelectBackward>)	tensor([-0.2771, -2.4187])
# -1.0	tensor([0.9986], grad_fn=<SelectBackward>)	tensor([-0.0899, -1.3386])
# 1.0	tensor([0.8512], grad_fn=<SelectBackward>)	tensor([-0.2155,  0.7580])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-2.2388, -1.2105])
# 1.0	tensor([0.9999], grad_fn=<SelectBackward>)	tensor([ 0.6713, -0.6435])
# -1.0	tensor([-1.0000], grad_fn=<SelectBackward>)	tensor([-0.8617, -0.9191])
# -1.0	tensor([-0.4362], grad_fn=<SelectBackward>)	tensor([0.5066, 0.1462])
# -1.0	tensor([-0.9986], grad_fn=<SelectBackward>)	tensor([-1.0036, -0.5019])
# -1.0	tensor([-0.9844], grad_fn=<SelectBackward>)	tensor([-0.7388, -1.4589])
# 1.0	tensor([0.2948], grad_fn=<SelectBackward>)	tensor([ 0.6822, -0.0131])
# 1.0	tensor([-0.0279], grad_fn=<SelectBackward>)	tensor([-1.8932,  0.1028])
# 1.0	tensor([0.9994], grad_fn=<SelectBackward>)	tensor([ 1.1726, -0.1528])
# -1.0	tensor([-0.9820], grad_fn=<SelectBackward>)	tensor([1.6517, 0.7501])
